# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
sonar_data = pd.read_csv(r'/content/drive/Othercomputers/My Laptop/Personal/AI/Python/Learning/Logistic Regression/SONAR Rock vs Mine Prediction/Copy of sonar data.csv', header=None)
#sonar_data.head()
#sonar_data.describe()
#sonar_data[60].value_counts //get the number of times a unique value appears., # 60 is the number of columns.
sonar_data.groupby(60).mean() # we divide the dataset by the values in the 60th column.

# Separating data and labels.
x = sonar_data.drop(columns=60, axis=1) # we drop the 60th column 
y = sonar_data[60] # We store the values of the 60th column in the Y variable.
# print(X)
# print(Y)

# %% [markdown]
# Training and Testing the Data.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, stratify=y, random_state=1)
#print(x.shape, x_train.shape, x_test.shape)

# %% [markdown]
# Applying Logistic Regression

# %%
model = LogisticRegression()

model.fit(x_train, y_train)

#accuracy on training data
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)

print('Accuracy on training data : ', training_data_accuracy)

#accuracy on test data
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction, y_test) 

print('Accuracy on test data : ', test_data_accuracy)
# Out:
# Accuracy on training data :  0.8342245989304813
# Accuracy on test data :  0.7619047619047619

# %% [markdown]
# Making a Predictive System.

# %%
input_data = {}

# changing the input_data to a numpy array.
input_data_as_numpy_array = np.asarray(input_data)

#reshaping the np array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 'R'):
  print('The object is a Rock.')
else:
  print('The object is a mine.')
